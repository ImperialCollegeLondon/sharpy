# %% [markdown]
# # Preliminary Horten Wing Response

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Analsysis Cases

# %% [markdown]
# ## Gust Response

# %%
data = pd.read_csv("output_gust_stable/data_gust_stable.csv")
data.head()
dt = 1/4/30
data['Time'] = data['Time']*dt
data.head()
# Out:
#        Time  N (stats)  Time (stats)  avg(X) (stats)  avg(Y) (stats)  \
# 0  0.000000          1             0    0.000000e+00    0.000000e+00
# 1  0.008333          1             1   -1.560510e-07   -9.078010e-08
# 2  0.016667          1             2   -6.219200e-07   -2.991870e-07
# 3  0.025000          1             3   -1.363730e-06   -4.543350e-07
# 4  0.033333          1             4   -2.338500e-06   -5.756510e-07
#
#    avg(Z) (stats)  avg(app_forces (0)) (stats)  avg(app_forces (1)) (stats)  \
# 0    0.000000e+00                     0.498073                -7.979970e-16
# 1   -8.665300e-07                     0.485266                 1.062620e-04
# 2   -6.784670e-06                     0.480720                 2.425670e-04
# 3   -2.167810e-05                     0.476738                 2.345280e-04
# 4   -4.693270e-05                     0.472982                 2.168020e-04
#
#    avg(app_forces (2)) (stats)  avg(app_forces (Magnitude)) (stats)  \
# ...

# %%
fig, (ax1, ax2) = plt.subplots(2,1, figsize = (12,10), dpi = 100)
line1 = ax1.plot(data['Time'], data['avg(Z) (stats)'], label = 'Z', linewidth = 2)
line2 = ax1.plot(data['Time'], data['avg(X) (stats)'], label = 'X', linewidth = 2)

plt.xlabel('Time, t [s]')
ax1.set_ylabel('Displacements, s [m]')
ax1.set_xlim([0,3.5])
ax1.legend()

ax1.grid(True)
ax2.set_ylabel('Applied Nodal Force, F_z [N]')

l3 = ax2.plot(data['Time'], data['avg(app_forces (2)) (stats)'], linewidth = 2)
ax2.set_xlim([0, 3.5])


plt.rcParams.update({'font.size': 16})


plt.grid()
plt.show()

# %% [markdown]
# ## Phugoid

# %%
phug_data = pd.read_csv("output_gust_stable/data_phugoid.csv")
phug_data['Time'] = phug_data['Time']*dt
phug_data.head()
# Out:
#        Time  X (stats)  Y (stats)  Z (stats)  app_forces (Magnitude) (stats)  \
# 0  0.000000   0.000000   0.000000   0.000000                        103.7410
# 1  0.008333  -0.249999  -0.000010   0.000481                        100.3420
# 2  0.016667  -0.499994  -0.000032   0.001633                         95.7237
# 3  0.025000  -0.749975  -0.000050   0.003147                         91.1747
# 4  0.033333  -0.999939  -0.000063   0.004930                         86.1192
#
#    app_moments (Magnitude) (stats)  coords_a (Magnitude) (stats)  \
# 0                          32.5122                             0
# 1                          31.7746                             0
# 2                          30.5309                             0
# 3                          29.1807                             0
# 4                          27.7732                             0
#
#    gravity_forces (Magnitude) (stats)  gravity_moments (Magnitude) (stats)  \
# ...

# %%
fig, (ax1, ax2) = plt.subplots(2,1, figsize = (12,10), dpi = 100)
line1 = ax1.plot(phug_data['Time'], phug_data['Z (stats)'], label = 'Z', linewidth = 2)
line2 = ax2.plot(phug_data['Time'], phug_data['X (stats)'], label = 'X', linewidth = 2)

# %% [markdown]
# ### Case 3

# %% [markdown]
# Case 3 test conditions:
#
# * Aircraft static
# * Oncoming velocity field with 1-cos gust
# * Lumped mass position `lumped_mass_position[2] = [0.0, -0.1, 0.]`

# %%
c3data = pd.read_csv("csv_data/data_case_003.csv")
dt = 1/4/30
c3data['Time'] = c3data['Time']*dt
c3data.head()
# Out:
#        Time  N (stats)  Time (stats)     X (stats)     Y (stats)  Z (stats)  \
# 0  0.000000          1             0  0.000000e+00  0.000000e+00   0.000000
# 1  0.008333          1             1 -2.936950e-08  1.825020e-08  -0.000001
# 2  0.016667          1             2 -1.176450e-07  2.969580e-08  -0.000006
# 3  0.025000          1             3 -2.446910e-07  1.830110e-08  -0.000016
# 4  0.033333          1             4 -3.700870e-07  2.652050e-08  -0.000032
#
#    app_forces (0) (stats)  app_forces (1) (stats)  app_forces (2) (stats)  \
# 0                0.492306           -8.469000e-16                 49.8222
# 1                0.482262           -1.791690e-05                 49.4881
# 2                0.481379           -1.987890e-05                 49.4435
# 3                0.480477            8.037610e-06                 49.4243
# 4                0.480091           -6.998860e-06                 49.4207
#
#    app_forces (Magnitude) (stats)            ...              \
# ...

# %%
fig, ax = plt.subplots(2,1, sharex=True, figsize = (12,10)) 

l1 = ax[0].plot(c3data['Time'],c3data['Z (stats)'], label = 'X', lw = 2)
l2 = ax[0].plot(c3data['Time'], c3data['X (stats)'], label = 'Z', lw = 2)

ax[0].legend()
ax[0].set_ylabel('Displacement, s [m]')

l3 = ax[1].plot(c3data['Time'], c3data['app_forces (2) (stats)'], label = 'F_z', lw = 2)
l4 = ax[1].plot(c3data['Time'], c3data['app_forces (0) (stats)'], label = 'F_x', lw = 2)
l5 = ax[1].plot(c3data['Time'], c3data['app_forces (1) (stats)'], label = 'F_y', lw = 2)


ax[1].legend()
ax[1].set_ylabel('Applied Force, F [N]')
ax[1].set_xlabel('Time, t (s)')
# Out:
# Text(0.5,0,'Time, t (s)')

# %% [markdown]
# ## Case 4

# %% [markdown]
# Case 4 conditions:
# * Lumped mass `Lumped mass position = [0, -0.05, 0]`
# * Steady aircraft
# * Gust velocity field `u_inf = 30`
# * Initial trim condition

# %%
c4data = pd.read_csv("csv_data/data_case_004.csv")
dt = 1/4/30
c4data['Time'] = c4data['Time']*dt
c4data.head()
# Out:
#        Time  N (stats)  Time (stats)     X (stats)     Y (stats)  Z (stats)  \
# 0  0.000000          1             0  0.000000e+00  0.000000e+00   0.000000
# 1  0.008333          1             1 -4.451900e-08 -1.580870e-09  -0.000002
# 2  0.016667          1             2 -1.809080e-07 -2.256540e-08  -0.000008
# 3  0.025000          1             3 -3.966610e-07 -6.099720e-08  -0.000020
# 4  0.033333          1             4 -6.532840e-07 -7.882680e-08  -0.000039
#
#    app_forces (0) (stats)  app_forces (1) (stats)  app_forces (2) (stats)  \
# 0                0.494641           -9.737620e-16                 49.9468
# 1                0.484095            1.690060e-06                 49.6099
# 2                0.482543            2.281660e-05                 49.5610
# 3                0.481062            4.692940e-05                 49.5368
# 4                0.480037            3.226160e-05                 49.5268
#
#    app_forces (Magnitude) (stats)            ...              \
# ...

# %%
U_z = c4data['Z (stats)'].diff()/c4data['Time'].diff()
U_x = c4data['X (stats)'].diff()/2/dt

AoA = np.arctan(U_z/(-U_x+30))

# %%
fig, ax = plt.subplots(2,1, figsize = (12,10), sharex= True)

ax[0].plot(c4data['Time'], c4data['Z (stats)'], label = 'Z', lw = 2)
ax[0].plot(c4data['Time'], c4data['X (stats)'], label = 'X', lw = 2)

ax[0].legend()
ax[0].set_ylabel('Displacement, s [m]')

ax[1].plot(c4data['Time'], c4data['app_forces (2) (stats)'], label = 'F_z', lw = 2)

ax[1].legend()
ax[1].set_ylabel('Applied Force, F [N]')
ax[1].set_xlabel('Time, t (s)')
# Out:
# Text(0.5,0,'Time, t (s)')

# %% [markdown]
# # Wake Analysis

# %% [markdown]
# Evaluate difference in aerodynamic resultant forces between a horseshoe vortex model and a discrete wake model

# %%
wake_data = pd.read_csv("csv_data/WakeConvergence.csv")

wake_data.groupby('m')

# %%
A = ~np.isinf(wake_data['WakeLength'])

# %%
B = wake_data['m']==4
C = wake_data['m']==6
wk4 = wake_data[A & B]
wk6 = wake_data[A & C]

# %%
fig, ax = plt.subplots(2,1, figsize = (12,10), sharex = True)

ax[0].plot(wk4['WakeLength'],100*wk4['Rel_Fz'], 
        label = 'm = 4',
        color = 'k',
        ls = '-',
        lw = 2)
ax[1].plot(wk4['WakeLength'], 100*wk4['Rel_Fx'],
        label = 'm = 4',
        color = 'k',
        ls = '-',
        lw = 2)
ax[0].plot(wk6['WakeLength'], 100*wk6['Rel_Fz'],
        label = 'm = 6',
        color = 'k',
        ls = '--',
        lw = 2)
ax[1].plot(wk6['WakeLength'], 100*wk6['Rel_Fx'],
        label = 'm = 6',
        color = 'k',
        ls = '--',
        lw = 2)

ax[0].legend()
ax[1].legend()

ax[0].set_ylabel('F_z Percentage Delta')
ax[1].set_ylabel('F_x Percentage Delta')

ax[1].set_xlabel('Wake Length [m]')

plt.savefig('/home/ng213/Documents/PhD/WeeklyMeetings/Wk6_181031/wake_study.eps')

# %% [markdown]
# # Pitch Angle

# %% [markdown]
# Inefficient way of calculating....

# %%
le = pd.read_csv('csv_data/gust_stable_LE.csv')
te = pd.read_csv('csv_data/gust_stable_TE.csv')

le['Time'] *= dt
te['Time'] *= dt

beam = pd.read_csv('output_gust_stable/data_gust_stable.csv')

# %%
theta = (le['Z (stats)']-te['Z (stats)'])/(le['X (stats)']-te['X (stats)'])
theta1 = np.arctan(beam['avg(local_y (2)) (stats)']/beam['avg(local_y (0)) (stats)'])

# %%
theta = np.arctan(theta)

# %%
plt.plot(le['Time'], theta)
plt.plot(beam['Time']*dt, theta1)

plt.xlabel('Time, t [s]')
plt.ylabel('Theta, [rad]')
# Out:
# Text(0,0.5,'Theta, [rad]')

# %% [markdown]
# # Effects of Inertia
#
# Running with j = 0.5mu. This one has the same dt. Beware for following because dt changes with the 1/2 scale. output_j05

# %% [markdown]
# `data_j005.csv` j=0.05mu and dt = 1/4/30*0.5
#
# Now running with inertia 5j and dt = 1/4/30*0.5

# %%
def make_plot(csv_file,dt):
    data = pd.read_csv(csv_file)
    data['Time'] *= dt
    
    fig, ax = plt.subplots(2,1,figsize = (12,10), sharex = True)
    
    ax[0].plot(data['Time'], data['Z (stats)'], lw = 2, label = 'Z')
    ax[0].plot(data['Time'], data['X (stats)'], lw = 2, label = 'X')
    
    ax[0].legend()
    ax[0].set_ylabel('Displacement, [m]')
    
    theta = -np.arctan(data['local_y (2) (stats)']/data['local_y (0) (stats)'])*180/np.pi
    
    ax[1].plot(data['Time'], theta, lw = 2)
    
    ax[1].set_ylabel('Pitch Angle, \\theta [deg]')
    
    ax[1].set_xlabel('Time, t [s]')
    
    return fig, ax, theta

# %%
def make_theta_plot(csv_file,dt):
    data = pd.read_csv(csv_file)
    data['Time'] *= dt
    
    fig = plt.figure(figsize = (12,10))
       
    theta = -np.arctan(data['local_y (2) (stats)']/data['local_y (0) (stats)'])*180/np.pi
    
    plt.plot(data['Time'], theta, lw = 2, color = 'k')
    
    plt.ylabel('Pitch Angle, \\theta [deg]')
    
    plt.xlabel('Time, t [s]')
    
    plt.grid()
    
    t = data['Time']
           
    return fig, theta, t

# %%
fig, theta05, t05 = make_theta_plot('csv_data/data_j05.csv', 1/4/30)
plt.xlim(0,3)
# Out:
# (0, 3)

# %%
fig, ax, theta = make_plot('csv_data/data_j05.csv', 1/4/30)
fig.suptitle('Inertia j = 0.5 mu')
ax[1].set_xlim(0,3)
ax[1].grid()

# %% [markdown]
# SPPO frequency approx 3Hz, oscillations die out after 4 cycles/1.5s

# %%
fig, ax, theta = make_plot('csv_data/data_j005.csv', 1/4/30/2)
fig.suptitle('Inertia j = 0.05 mu')

ax[1].set_xlim((0,2))
ax[1].grid()

# %%
fig, theta005, t005 = make_theta_plot('csv_data/data_j005.csv', 1/4/30/2)

plt.xlim(0,2.5)
# Out:
# (0, 2.5)

# %%
fig, theta001, t001 = make_theta_plot('csv_data/data_j001.csv', 1/4/30/2)

# %%
fig = plt.figure(figsize=(12,10))

plt.plot(t001, theta001, lw = 2, ls = ':', color = 'k', label = 'j = 0.017')
plt.plot(t005, theta005, lw = 2, ls = '--', color = 'k', label = 'j = 0.5')
plt.plot(t05, theta05, lw = 2, ls = '-', color = 'k', label = 'j = 5')


plt.ylabel('Pitch angle, \\theta [deg]')
plt.xlim(0,3)
plt.legend()
plt.grid

plt.title('U_inf = 30 m/s, Trim Condition, 1-cos gust')

plt.grid()
plt.xlabel('Time, t [s]')

plt.savefig('/home/ng213/Documents/PhD/WeeklyMeetings/Wk6_181031/SPPO_inertia.eps', dpi = 200)

# %% [markdown]
# For low inertia cases it is clear inertia is insignificant as the response is clearly dominated by the gust profile and the two cases are pretty much identical in that timeframe

# %%
fig, ax, theta5 = make_plot('csv_data/data_j5_root.csv', 1/4/30/2)
fig.suptitle('Inertia j = 5 mu')

#ax[1].set_xlim((0,2))
ax[1].grid()

# %%
rd = pd.read_csv('csv_data/data_j05.csv')
td = pd.read_csv('csv_data/data_j05_wingtip.csv')
dt = 1/4/30

t = rd['Time'] * dt

# %%
fig, ax = plt.subplots(3,1, figsize = (12,10), sharex = True)


#plt.plot(t, rd['Z (stats)'])
tdz = td['Z (stats)']
rdz = rd['Z (stats)']
ds = tdz-rdz
# ax[0].plot(t, tdz)
ax[0].plot(t, ds, lw = 2, ls = '-', color = 'k')
ax[0].set_ylabel('Tip Rel Displacement, [m]')

ax[1].plot(t, theta05, lw = 2, ls = '-', color = 'k')
ax[1].set_ylabel('Pitch, [deg]')


norm = -ds/np.min(ds)
ax[2].plot(t, norm -norm[0], lw = 2, ls = '-', color = 'k', label = 'Bending')

norm1 = theta05/np.max(theta05)
ax[2].plot(t, norm1-norm1[0], lw = 2, ls = '-.', color = 'k', label = 'Pitch')
ax[2].legend()

ax[2].set_xlabel('Time, t [s]')
plt.xlim(0,2.5)

plt.savefig('/home/ng213/Documents/PhD/WeeklyMeetings/Wk6_181031/BendPitch_j05.eps')

# %%
np.max(ds)
# Out:
# -0.0934521

# %%
rd = pd.read_csv('csv_data/data_j5_root.csv')
td = pd.read_csv('csv_data/data_j5_wingtip.csv')
dt = 1/4/30/2

t = rd['Time'] * dt

rd['Z (stats)'].count()
td['Z (stats)'].count()
# Out:
# 852

# %%
fig, ax = plt.subplots(3,1, figsize = (12,10), sharex = True)


#plt.plot(t, rd['Z (stats)'])
tdz = td['Z (stats)']
rdz = rd['Z (stats)']
ds = tdz-rdz
# ax[0].plot(t, tdz)
ax[0].plot(t, ds, lw = 2, ls = '-', color = 'k')
ax[0].set_ylabel('Tip Rel Displacement, [m]')

ax[1].plot(t, theta5, lw = 2, ls = '-', color = 'k')
ax[1].set_ylabel('Pitch, [deg]')


norm = -ds/np.min(ds)
ax[2].plot(t, norm -norm[0], lw = 2, ls = '-', color = 'k', label = 'Bending')

norm1 = theta5/np.max(theta5)
ax[2].plot(t, norm1-norm1[0], lw = 2, ls = '-.', color = 'k', label = 'Pitch')
ax[2].legend()

ax[2].set_xlabel('Time, t [s]')
plt.xlim(0,2.5)

plt.savefig('/home/ng213/Documents/PhD/WeeklyMeetings/Wk6_181031/BendPitch_j5.eps')

# %% [markdown]
# # Effect of stiffness

# %% [markdown]
# ## Case 1
#
# `sigma = 0.5`
#
# `j = 0.017028` kg m
#
# `u_inf = 30` m/s

# %%
fig, theta_sigma_5, t_sigma05 = make_theta_plot('csv_data/data_sigma05_root.csv', 1/4/30/2)

plt.xlim(0,8)
# Out:
# (0, 8)

# %%
fig, ax = plt.subplots(2,1,sharex = True, figsize = (12,10))
sig05root = pd.read_csv('csv_data/data_sigma05_root.csv')
sig05tip = pd.read_csv('csv_data/data_sigma05_tip.csv')

root_d = sig05root['Z (stats)']
tip_d = sig05tip['Z (stats)']
ax[0].plot(t_sigma05, tip_d, ls = '-', color = 'b', lw = 2)
ax[0].plot(t_sigma05, root_d, ls = '-', color = 'k', lw = 2)
ax[0].plot(t_sigma05, tip_d-tip_d[0]-root_d, ls = '-', color = 'r', lw = 2)

# ax[0].plot(t_sigma05, tip_d-root_d, ls = '-', color = 'k', lw = 2)
# ax[0].plot(t_sigma05, sig05tip['Z (stats)'], ls = '--', color = 'k', lw = 2)

norm_theta_sigma05 = theta_sigma_5/np.max(theta_sigma_5)
norm_disp_sigma05 = (tip_d-tip_d[0]-root_d)/np.max((tip_d-root_d-tip_d[0]))
ax[1].plot(t_sigma05, theta_sigma_5-theta_sigma_5[0], ls = '-', color = 'k', lw = 2)
ax[1].plot(t_sigma05, norm_disp_sigma05, ls = '-', color = 'b', lw = 2)

ax[1].set_xlim(0,5)
# Out:
# (0, 5)

# %%
fig, ax = plt.subplots(figsize = (12,10))

ax.plot(t_sigma05, theta_sigma_5-theta_sigma_5[0], ls = '-', color = 'k', lw = 2, label = 'Change in Pitch')

ax.set_xlim(0,4)

ax.set_xlabel('Time, t [s]')
ax.set_ylabel('Pitch Angle Delta, [deg]')

ax1 = ax.twinx()
ax1.plot(t_sigma05, tip_d-root_d-tip_d[0], ls = '-', color = 'b', lw = 2, label = 'Tip Displacement')
ax1.tick_params('y', colors = 'b')
ax1.set_ylabel('Wing Tip Displacement Delta, [m]', color = 'b')

plt.savefig('/home/ng213/Documents/PhD/WeeklyMeetings/Wk6_181031/Sigma05_u30_BFFmode.eps')

# %% [markdown]
# ## Case 2
#
# __RUNNING__
#
# `sigma = 0.5`
#
# `j = 0.017028` kg m
#
# `u_inf = 35` m/s

# %%
fig, theta_sigma_5_u35, t_sigma05_u35 = make_theta_plot('csv_data/data_sigma05_root_u35.csv', 1/4/35/2)

plt.xlim(0,6)
# Out:
# (0, 6)

# %%
fig, ax = plt.subplots(2,1,sharex = True, figsize = (12,10))
sig05root_u35 = pd.read_csv('csv_data/data_sigma05_root_u35.csv')
sig05tip_u35 = pd.read_csv('csv_data/data_sigma05_tip_u35.csv')

root_d_u35 = sig05root_u35['Z (stats)']
tip_d_u35 = sig05tip_u35['Z (stats)']
ax[0].plot(t_sigma05_u35, tip_d_u35, ls = '-', color = 'b', lw = 2)
ax[0].plot(t_sigma05_u35, root_d_u35, ls = '-', color = 'k', lw = 2)
ax[0].plot(t_sigma05_u35, tip_d_u35-tip_d_u35[0]-root_d_u35, ls = '-', color = 'r', lw = 2)

# ax[0].plot(t_sigma05, tip_d-root_d, ls = '-', color = 'k', lw = 2)
# ax[0].plot(t_sigma05, sig05tip['Z (stats)'], ls = '--', color = 'k', lw = 2)

norm_disp_sigma05_u35 = (tip_d_u35-tip_d_u35[0]-root_d_u35)/np.max((tip_d_u35-root_d-tip_d_u35[0]))
ax[1].plot(t_sigma05_u35, theta_sigma_5_u35-theta_sigma_5_u35[0], ls = '-', color = 'k', lw = 2)
ax[1].plot(t_sigma05_u35, norm_disp_sigma05_u35, ls = '-', color = 'b', lw = 2)

ax[1].set_xlim(0,6)
# Out:
# (0, 6)

# %%
fig, ax = plt.subplots(figsize = (12,10))

ax.plot(t_sigma05_u35, theta_sigma_5_u35-theta_sigma_5_u35[0], ls = '-', color = 'k', lw = 2, label = 'Change in Pitch')

ax.set_xlim(0,6)

ax.set_xlabel('Time, t [s]')
ax.set_ylabel('Pitch Angle Delta, [deg]')

ax1 = ax.twinx()
ax1.plot(t_sigma05_u35, tip_d_u35-root_d_u35-tip_d_u35[0], ls = '-', color = 'b', lw = 2, label = 'Tip Displacement')
ax1.tick_params('y', colors = 'b')
ax1.set_ylabel('Wing Tip Displacement Delta, [m]', color = 'b')

plt.savefig('/home/ng213/Documents/PhD/WeeklyMeetings/Wk6_181031/Sigma05_u35_BFFmode.eps')

# %% [markdown]
# # Richard's Stiffness Matrix
#
# Run with solely the bending degree of freedom

# %%
fig = make_plot('csv_data/richards_u30.csv', 1/30/4/2)

# %% [markdown]
# # Coordinate Comparison

# %%
coords = pd.read_csv('coords_comparison.csv')
coords.head()
# Out:
#         y_r  Unnamed: 1       x_r  Unnamed: 3       x_g       y_g
# 0 -0.010230    0.043361 -0.043361         NaN  0.000000  0.000000
# 1  0.496164    0.045938 -0.045938         NaN  0.000000  0.412500
# 2  0.987212   -0.150036  0.150036         NaN  0.000000  0.825000
# 3  1.493606   -0.315398  0.315398         NaN  0.087880  1.066447
# 4  2.000000   -0.480760  0.480760         NaN  0.175759  1.307895

# %%
fig, ax = plt.subplots(1,1, figsize = (12,10))

ax.plot(coords['y_r'], coords['x_r'], ls = '-')
ax.plot(coords['y_g'], coords['x_g'])

# %% [markdown]
# # Modelling Issues
#
# ## Stop NaN in lu_solv
#
# This occurs after 50-100 iterations when the fsi iterations start going towards the upper limit. It is often the case with the refined model for some reason.
#
# Conditions in which this has occured are:
# * `sigma_richards = 1000.`
# * `m = 6`
# * `num_wing_elem = 19`
#
# The stiffness matrix with the above condition becomes unphysiscal, with 5 orders of magnitude difference between EI_x and EI_z
#
#
# ## Fuselage width
#
# Noticed from Richards' paper that the wing offset value of 1.65m given does not correspond to the FEA model presented as a figure. The comparison is shown above. Test cases now running with `fuselage_width = 1.`

# %% [markdown]
# ### Test case
#
# Properties:
# * `fuselage_width = 1`
# * `u_inf = 32`
# * `tstep_factor = 1`
# * `sigma_richards = 1`

# %%
fus_1 = pd.read_csv('csv_data/fus1_sigr1_v32.csv')
dt = 1/32/6

fus_1['Time'] *= dt

# %%
theta = -np.arctan(fus_1['local_y (2) (stats)']/fus_1['local_y (0) (stats)'])*180/np.pi

# %%
fig, ax = plt.subplots(1,1,figsize = (12,10))

ax.plot(fus_1['Time'], theta, ls = '-', lw = 2, color = 'k')

ax.set_xlim(0,3)
ax.set_xlabel('Time, t [s]')
ax.set_ylabel('Pitch Angle, /theta [deg]')
# Out:
# Text(0,0.5,'Pitch Angle, /theta [deg]')

# %%
N = fus_1.index[fus_1['Time']>=3].tolist()[0]
T = fus_1['Time'][N]
dt = fus_1['Time'][1]-fus_1['Time'][0]

yf = np.fft.fft(theta)
xf = np.linspace(0.0, 1.0/(2.0*T), int(N/2))

plt.plot(xf, 2.0/N * np.abs(yf[:N//2]))

# %%
xf = yf.shape

# %% [markdown]
# Structural modes frequencies (in vacuo) for this configuration:
# * 10.09 rad/s
# * 46.29 rad/s

# %% [markdown]
# ### Test Case - Horten 2 results with
#
# * u = 40 m/s
# * m = 4, n = 11
# * Stiffness matrix with EA, GA *100; GJ *1000 and EI_z *10

# %%
data = pd.read_csv('csv_data/horten2_u40.csv')
dt = 1/4/40/2
data['Time'] *= dt

# %%
theta = -np.arctan(data['local_y (2) (stats)']/data['local_y (0) (stats)'])*180/np.pi

# %%
fig, ax = plt.subplots(1,1,figsize = (12,10))

ax.plot(data['Time'], theta, ls = '-', lw = 2, color = 'k')

ax.set_xlim(0,3)
ax.set_xlabel('Time, t [s]')
ax.set_ylabel('Pitch Angle, /theta [deg]')
# Out:
# Text(0,0.5,'Pitch Angle, /theta [deg]')

# %% [markdown]
# In-vacuo frequencies:
# 1.

# %% [markdown]
# # Gamma dot

# %%
gamma_dot = pd.read_csv("../horten_m/output_steady/output/horten/WriteVariablesTime/aero_gamma_dot_panel_isurf0_im1_in-2.dat",
                        sep = None, header = None)
gamma = pd.read_csv("../horten_m/output_steady/output/horten/WriteVariablesTime/aero_gamma_panel_isurf0_im1_in-2.dat",
                        sep = None, header = None)
# Out:
# /home/ng213/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support sep=None with delim_whitespace=False; you can avoid this warning by specifying engine='python'.
#
# /home/ng213/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support sep=None with delim_whitespace=False; you can avoid this warning by specifying engine='python'.
#   after removing the cwd from sys.path.

# %%
dt = 1/4/36/2

t = gamma_dot[0]*dt
tg = gamma[0]*dt

# %%
# Finite Difference
dgamma = np.diff(gamma[1])/dt

# Second order

# %%
fig = plt.figure(figsize=(12,10))
plt.plot(t, gamma_dot[1], label = 'gamma_dot', lw = 2)
plt.plot(tg, gamma[1], label = 'gamma', lw = 2)

plt.plot(tg[:-1], dgamma)
plt.ylim(-5,5)
plt.legend()
plt.xlabel('Time, t [s]')
# Out:
# Text(0.5,0,'Time, t [s]')

# %%
gamma_dot = pd.read_csv("../horten_m/output_unsteady_blows/horten/WriteVariablesTime/aero_gamma_dot_panel_isurf0_im1_in-2.dat",
                        sep = None, header = None)
gamma = pd.read_csv("../horten_m/output_unsteady_blows/horten/WriteVariablesTime/aero_gamma_panel_isurf0_im1_in-2.dat",
                        sep = None, header = None)
dt = 1/4/36/2

t = gamma_dot[0]*dt
tg = gamma[0]*dt
# Out:
# /home/ng213/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support sep=None with delim_whitespace=False; you can avoid this warning by specifying engine='python'.
#
# /home/ng213/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support sep=None with delim_whitespace=False; you can avoid this warning by specifying engine='python'.
#   after removing the cwd from sys.path.

# %%
fig = plt.figure(figsize=(12,10))
plt.plot(t, gamma_dot[1], label = 'gamma_dot', lw = 2)
plt.plot(tg, gamma[1], label = 'gamma', lw = 2)
plt.ylim(-5,5)
plt.legend()
plt.xlabel('Time, t [s]')
# Out:
# Text(0.5,0,'Time, t [s]')
